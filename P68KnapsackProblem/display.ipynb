# %%
import optuna

num = 15
study_name = f"knapsack_size{num}"
study = optuna.create_study(study_name=study_name,storage='sqlite:///../optuna_study.db', load_if_exists=True,direction='maximize')
df = study.trials_dataframe()
df.head()
# Out:
# [I 2020-11-20 09:41:38,614] Using an existing study with name 'knapsack_size15' instead of creating a new one.
#    number  value             datetime_start          datetime_complete  \
# 0       0    0.0 2020-11-19 10:19:32.318687 2020-11-19 10:20:06.732471
# 1       1    0.0 2020-11-19 10:20:06.752899 2020-11-19 10:20:42.447351
# 2       2  454.0 2020-11-19 10:20:42.467847 2020-11-19 10:21:19.700856
# 3       3    0.0 2020-11-19 10:21:19.722466 2020-11-19 10:21:55.093534
# 4       4    0.0 2020-11-19 10:21:55.115201 2020-11-19 10:22:33.178505
#
#          duration  params_balancer     state
# 0 00:00:34.413784         7.433365  COMPLETE
# 1 00:00:35.694452         1.965805  COMPLETE
# 2 00:00:37.233009         1.123123  COMPLETE
# 3 00:00:35.371068         8.412590  COMPLETE
# 4 00:00:38.063304         7.345303  COMPLETE

# %%
df.plot(x="params_balancer",y="value",kind='scatter')

# %%
num = 15
study_name = f"knapsack_size{num}withy"
study = optuna.create_study(study_name=study_name,storage='sqlite:///../optuna_study.db', load_if_exists=True,direction='maximize')
df = study.trials_dataframe()
df.head()
# Out:
# [I 2020-11-20 09:41:39,380] Using an existing study with name 'knapsack_size15withy' instead of creating a new one.
#    number  value             datetime_start          datetime_complete  \
# 0       0   11.0 2020-11-19 21:36:31.802426 2020-11-19 21:37:17.637472
# 1       1    0.0 2020-11-19 21:37:17.662346 2020-11-19 21:38:11.382127
# 2       2    0.0 2020-11-19 21:38:11.405716 2020-11-19 21:39:04.868243
# 3       3    0.0 2020-11-19 21:39:04.889931 2020-11-19 21:39:56.465843
# 4       4    0.0 2020-11-19 21:39:56.487140 2020-11-19 21:40:57.439600
#
#          duration  params_balancer     state
# 0 00:00:45.835046         9.888583  COMPLETE
# 1 00:00:53.719781         1.709543  COMPLETE
# 2 00:00:53.462527         5.888535  COMPLETE
# 3 00:00:51.575912         7.265501  COMPLETE
# 4 00:01:00.952460         7.982132  COMPLETE

# %%
df.plot(x="params_balancer",y="value",kind='scatter')

# %%
num = 15
study_name = f"knapsack_size{num}withy_range30"
study = optuna.create_study(study_name=study_name,storage='sqlite:///../optuna_study.db', load_if_exists=True,direction='maximize')
df = study.trials_dataframe()
df.head()
df.plot(x="params_balancer",y="value",kind='scatter')
